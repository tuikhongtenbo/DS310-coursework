# %% [markdown]
# ## vLLM setting

# %%
# !nvidia-smi

import sys, torch
print("Python:", sys.version)
print("Torch:", torch.__version__)
print("Torch CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Compute capability:", torch.cuda.get_device_capability(0))
# Out:
# Tue Jan  6 05:12:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   42C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Torch: 2.6.0+cu124
# Torch CUDA: 12.4
# CUDA available: True
# GPU: Tesla T4
# Compute capability: (7, 5)

# %%
import os
os.environ["HF_HOME"] = "/content/hf_cache"
os.environ["TRANSFORMERS_CACHE"] = "/content/hf_cache"
os.environ["HF_HUB_DISABLE_TELEMETRY"] = "1"
print("HF_HOME =", os.environ["HF_HOME"])
# Out:
# HF_HOME = /content/hf_cache

# %%
# !pip -q uninstall -y transformers tokenizers
# !pip -q install -U "transformers==4.45.2" "tokenizers==0.20.3" "accelerate>=0.33.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 78.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 102.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.9 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)

# %%
# %%capture
# 1) Cài PyTorch CUDA 12.1 (để tránh pip kéo nhầm torch CPU)
# !pip -q install -U --index-url https://download.pytorch.org/whl/cu121 \
  torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0

# 2) Cài vLLM (pin bản 0.6.6.post1) + các lib hay cần cho HF
# !pip -q install -U \
  vllm==0.6.6.post1 \
  transformers accelerate sentencepiece safetensors tqdm

# %% [markdown]
# ## Test vLLM

# %%
import transformers, vllm, torch

print("transformers:", transformers.__version__)
print("vllm:", vllm.__version__)
print("torch:", torch.__version__, "CUDA:", torch.version.cuda)
# Out:
# 2026-01-06 05:19:36.212518: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767676776.401176     209 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767676776.456440     209 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# transformers: 4.57.3
# vllm: 0.6.6.post1
# torch: 2.5.1+cu124 CUDA: 12.4

# %%
# !ls -lh /kaggle/working/Private_Test_ref.json \
        /kaggle/working/ground_truth_private_test.json \
        /kaggle/working/llama_infer.py \
        /kaggle/working/evaluation.py

# !mkdir -p /kaggle/working/predictions /kaggle/working/results /kaggle/working/logs
# !ls -lh /kaggle/working/predictions /kaggle/working/results /kaggle/working/logs
# Out:
# ls: cannot access '/kaggle/working/Private_Test_ref.json': No such file or directory
# ls: cannot access '/kaggle/working/ground_truth_private_test.json': No such file or directory
# ls: cannot access '/kaggle/working/llama_infer.py': No such file or directory
# ls: cannot access '/kaggle/working/evaluation.py': No such file or directory
# /kaggle/working/logs:
# total 0
#
# /kaggle/working/predictions:
# total 0
#
# /kaggle/working/results:
# total 0

# %%
# !cp /kaggle/input/logging/logger.py /kaggle/working/logger.py
# !ls -l /kaggle/working/logger.py
# Out:
# -rw-r--r-- 1 root root 2622 Jan  6 05:19 /kaggle/working/logger.py

# %% [markdown]
# ## Qwen inference

# %% [markdown]
# ##### Few-shot

# %%
# !python /kaggle/input/infer-of-llama-main/llama_infer.py \
  --input_file /kaggle/input/uit-viquad-2-0/Private_Test_ref.json \
  --output_file /kaggle/working/predictions_llama_few.json \
  --model_name hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4 \
  --mode few-shot \
  --max_new_tokens 32 \
  --temperature 0.0 \
  --top_p 0.7 \
  --max_model_len 8192 \
  --batch_size 8 \
  --tensor_parallel_size 2 \
  --gpu_memory_utilization 0.9 \
  --log_dir /kaggle/working/logs
# Out:
# 2026-01-06 05:22:01.181093: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767676921.202168     259 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767676921.208518     259 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2026-01-06 05:22:10 - INFO - Logger initialized. Log file: /kaggle/working/logs/llama_infer_20260106_052210.log
# INFO:llama_infer:Logger initialized. Log file: /kaggle/working/logs/llama_infer_20260106_052210.log
# 2026-01-06 05:22:10 - INFO - Loading examples from /kaggle/input/uit-viquad-2-0/Private_Test_ref.json
# INFO:llama_infer:Loading examples from /kaggle/input/uit-viquad-2-0/Private_Test_ref.json
# 2026-01-06 05:22:10 - INFO - Loaded 7301 examples
# INFO:llama_infer:Loaded 7301 examples
# 2026-01-06 05:22:10 - INFO - Initializing vLLM for hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4 (AWQ 4-bit)
# INFO:llama_infer:Initializing vLLM for hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4 (AWQ 4-bit)
# 2026-01-06 05:22:10 - INFO -   Tensor parallel size: 2
# INFO:llama_infer:  Tensor parallel size: 2
# 2026-01-06 05:22:10 - INFO -   GPU memory utilization: 0.9
# INFO:llama_infer:  GPU memory utilization: 0.9
# 2026-01-06 05:22:10 - INFO -   Batch size: 8
# INFO:llama_infer:  Batch size: 8
# 2026-01-06 05:22:10 - INFO -   Max new tokens: 32
# INFO:llama_infer:  Max new tokens: 32
# 2026-01-06 05:22:10 - INFO -   Temperature: 0.0, Top-p: 0.7
# INFO:llama_infer:  Temperature: 0.0, Top-p: 0.7
# config.json: 1.04kB [00:00, 4.47MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 01-06 05:22:29 config.py:510] This model supports multiple tasks: {'generate', 'embed', 'reward', 'classify', 'score'}. Defaulting to 'generate'.
# WARNING 01-06 05:22:30 config.py:588] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# INFO 01-06 05:22:30 config.py:1310] Defaulting to use mp for distributed inference
# INFO 01-06 05:22:30 llm_engine.py:234] Initializing an LLM engine (v0.6.6.post1) with config: model='hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4', speculative_config=None, tokenizer='hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=2, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=awq, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"candidate_compile_sizes":[],"compile_sizes":[],"capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# tokenizer_config.json: 55.4kB [00:00, 112MB/s]
# tokenizer.json: 9.09MB [00:00, 97.2MB/s]
# special_tokens_map.json: 100%|█████████████████| 295/295 [00:00<00:00, 2.24MB/s]
# generation_config.json: 100%|██████████████████| 189/189 [00:00<00:00, 1.21MB/s]
# WARNING 01-06 05:22:32 multiproc_worker_utils.py:280] CUDA was previously initialized. We must use the `spawn` multiprocessing start method. Setting VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/getting_started/debugging.html#python-multiprocessing for more information.
# WARNING 01-06 05:22:32 multiproc_worker_utils.py:312] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 01-06 05:22:32 custom_cache_manager.py:17] Setting Triton cache manager to: vllm.triton_utils.custom_cache_manager:CustomCacheManager
# INFO 01-06 05:22:32 selector.py:217] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 01-06 05:22:32 selector.py:129] Using XFormers backend.
# 2026-01-06 05:22:36.580112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767676956.601182     297 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767676956.608426     297 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# (VllmWorkerProcess pid=297) INFO 01-06 05:22:48 selector.py:217] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# (VllmWorkerProcess pid=297) INFO 01-06 05:22:48 selector.py:129] Using XFormers backend.
# (VllmWorkerProcess pid=297) INFO 01-06 05:22:48 multiproc_worker_utils.py:222] Worker ready; awaiting tasks
# INFO 01-06 05:22:48 utils.py:918] Found nccl from library libnccl.so.2
# (VllmWorkerProcess pid=297) INFO 01-06 05:22:48 utils.py:918] Found nccl from library libnccl.so.2
# INFO 01-06 05:22:48 pynccl.py:69] vLLM is using nccl==2.21.5
# (VllmWorkerProcess pid=297) INFO 01-06 05:22:48 pynccl.py:69] vLLM is using nccl==2.21.5
# INFO 01-06 05:22:49 custom_all_reduce_utils.py:204] generating GPU P2P access cache in /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# INFO 01-06 05:23:22 custom_all_reduce_utils.py:242] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:22 custom_all_reduce_utils.py:242] reading GPU P2P access cache from /root/.cache/vllm/gpu_p2p_access_cache_for_0,1.json
# INFO 01-06 05:23:22 shm_broadcast.py:255] vLLM message queue communication handle: Handle(connect_ip='127.0.0.1', local_reader_ranks=[1], buffer_handle=(1, 4194304, 6, 'psm_21399722'), local_subscribe_port=42019, remote_subscribe_port=None)
# INFO 01-06 05:23:22 model_runner.py:1094] Starting to load model hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4...
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:22 model_runner.py:1094] Starting to load model hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4...
# INFO 01-06 05:23:22 weight_utils.py:251] Using model weights format ['*.safetensors']
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:22 weight_utils.py:251] Using model weights format ['*.safetensors']
# model-00001-of-00002.safetensors: 100%|█████| 4.68G/4.68G [00:10<00:00, 456MB/s]
# model-00002-of-00002.safetensors: 100%|█████| 1.05G/1.05G [00:03<00:00, 330MB/s]
# model.safetensors.index.json: 63.5kB [00:00, 117MB/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:01<00:01,  1.07s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:05<00:00,  3.12s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:05<00:00,  2.81s/it]
#
# INFO 01-06 05:23:42 model_runner.py:1099] Loading model weights took 2.7007 GB
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:47 model_runner.py:1099] Loading model weights took 2.7007 GB
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:55 worker.py:241] Memory profiling takes 7.67 seconds
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:55 worker.py:241] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.90) = 13.27GiB
# (VllmWorkerProcess pid=297) INFO 01-06 05:23:55 worker.py:241] model weights take 2.70GiB; non_torch_memory takes 0.37GiB; PyTorch activation peak memory takes 0.52GiB; the rest of the memory reserved for KV Cache is 9.67GiB.
# INFO 01-06 05:23:55 worker.py:241] Memory profiling takes 7.77 seconds
# INFO 01-06 05:23:55 worker.py:241] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.90) = 13.27GiB
# INFO 01-06 05:23:55 worker.py:241] model weights take 2.70GiB; non_torch_memory takes 0.37GiB; PyTorch activation peak memory takes 1.23GiB; the rest of the memory reserved for KV Cache is 8.96GiB.
# INFO 01-06 05:23:55 distributed_gpu_executor.py:57] # GPU blocks: 9179, # CPU blocks: 4096
# INFO 01-06 05:23:55 distributed_gpu_executor.py:61] Maximum concurrency for 8192 tokens per request: 17.93x
# INFO 01-06 05:23:59 model_runner.py:1415] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|                       | 0/35 [00:00<?, ?it/s](VllmWorkerProcess pid=297) INFO 01-06 05:23:59 model_runner.py:1415] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████████| 35/35 [00:41<00:00,  1.19s/it]
# INFO 01-06 05:24:40 custom_all_reduce.py:224] Registering 2275 cuda graph addresses
# (VllmWorkerProcess pid=297) INFO 01-06 05:24:40 custom_all_reduce.py:224] Registering 2275 cuda graph addresses
# (VllmWorkerProcess pid=297) INFO 01-06 05:24:40 model_runner.py:1535] Graph capturing finished in 41 secs, took 0.36 GiB
# INFO 01-06 05:24:40 model_runner.py:1535] Graph capturing finished in 42 secs, took 0.36 GiB
# INFO 01-06 05:24:40 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 53.23 seconds
# 2026-01-06 05:24:40 - INFO - Generating predictions with mode=few-shot
# INFO:llama_infer:Generating predictions with mode=few-shot
# Generating:   0%|                                                           | 0/913 [00:00<?, ?it/s]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.01it/s, est. speed input: 1483.9
# Generating:   0%|                                                 | 1/913 [00:04<1:01:09,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.02it/s, est. speed input: 1735.8
# Generating:   0%|                                                 | 2/913 [00:07<1:00:38,  3.99s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.14it/s, est. speed input: 1693.9
# Generating:   0%|▏                                                  | 3/913 [00:11<58:56,  3.89s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.32it/s, est. speed input: 1645.3
# Generating:   0%|▏                                                  | 4/913 [00:15<56:22,  3.72s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.30it/s, est. speed input: 1644.1
# Generating:   1%|▎                                                  | 5/913 [00:18<55:02,  3.64s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.26it/s, est. speed input: 1654.1
# Generating:   1%|▎                                                  | 6/913 [00:22<54:32,  3.61s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.23it/s, est. speed input: 1632.9
# Generating:   1%|▍                                                  | 7/913 [00:25<54:29,  3.61s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.26it/s, est. speed input: 1627.2
# Generating:   1%|▍                                                  | 8/913 [00:29<54:10,  3.59s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.30it/s, est. speed input: 1619.5
# Generating:   1%|▌                                                  | 9/913 [00:32<53:37,  3.56s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.28it/s, est. speed input: 1604.4
# Generating:   1%|▌                                                 | 10/913 [00:36<53:25,  3.55s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.18it/s, est. speed input: 1585.3
# Generating:   1%|▌                                                 | 11/913 [00:40<54:01,  3.59s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.21it/s, est. speed input: 1578.7
# Generating:   1%|▋                                                 | 12/913 [00:43<54:08,  3.61s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.18it/s, est. speed input: 1558.0
# Generating:   1%|▋                                                 | 13/913 [00:47<54:26,  3.63s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.10it/s, est. speed input: 1514.5
# Generating:   2%|▊                                                 | 14/913 [00:51<55:15,  3.69s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.19it/s, est. speed input: 1528.9
# Generating:   2%|▊                                                 | 15/913 [00:54<55:07,  3.68s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.12it/s, est. speed input: 1500.3
# Generating:   2%|▉                                                 | 16/913 [00:58<55:31,  3.71s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1521.8
# Generating:   2%|▉                                                 | 17/913 [01:02<56:53,  3.81s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1489.5
# Generating:   2%|▉                                                 | 18/913 [01:06<58:38,  3.93s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1447.6
# Generating:   2%|█                                                 | 19/913 [01:11<59:49,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.64it/s, est. speed input: 1491.0
# Generating:   2%|█                                               | 20/913 [01:16<1:03:45,  4.28s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.52it/s, est. speed input: 1512.5
# Generating:   2%|█                                               | 21/913 [01:21<1:08:11,  4.59s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.44it/s, est. speed input: 1509.0
# Generating:   2%|█▏                                              | 22/913 [01:26<1:12:27,  4.88s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.55it/s, est. speed input: 1543.7
# Generating:   3%|█▏                                              | 23/913 [01:32<1:13:41,  4.97s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.46it/s, est. speed input: 1582.2
# Generating:   3%|█▎                                              | 24/913 [01:37<1:15:58,  5.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.38it/s, est. speed input: 1637.4
# Generating:   3%|█▎                                              | 25/913 [01:43<1:19:00,  5.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.37it/s, est. speed input: 1639.7
# Generating:   3%|█▎                                              | 26/913 [01:49<1:21:21,  5.50s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.64it/s, est. speed input: 1627.7
# Generating:   3%|█▍                                              | 27/913 [01:54<1:18:32,  5.32s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.85it/s, est. speed input: 1606.7
# Generating:   3%|█▍                                              | 28/913 [01:58<1:14:06,  5.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.60it/s, est. speed input: 1614.5
# Generating:   3%|█▌                                              | 29/913 [02:03<1:14:02,  5.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:06<00:00,  1.25it/s, est. speed input: 1690.8
# Generating:   3%|█▌                                              | 30/913 [02:10<1:20:02,  5.44s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:06<00:00,  1.29it/s, est. speed input: 1665.7
# Generating:   3%|█▋                                              | 31/913 [02:16<1:23:21,  5.67s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.51it/s, est. speed input: 1611.2
# Generating:   4%|█▋                                              | 32/913 [02:21<1:21:45,  5.57s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1555.5
# Generating:   4%|█▋                                              | 33/913 [02:25<1:15:40,  5.16s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.87it/s, est. speed input: 1580.6
# Generating:   4%|█▊                                              | 34/913 [02:30<1:11:46,  4.90s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1513.1
# Generating:   4%|█▊                                              | 35/913 [02:34<1:07:55,  4.64s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.97it/s, est. speed input: 1478.1
# Generating:   4%|█▉                                              | 36/913 [02:38<1:05:20,  4.47s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.88it/s, est. speed input: 1559.5
# Generating:   4%|█▉                                              | 37/913 [02:42<1:04:26,  4.41s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1504.6
# Generating:   4%|█▉                                              | 38/913 [02:46<1:03:26,  4.35s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1520.2
# Generating:   4%|██                                              | 39/913 [02:50<1:02:39,  4.30s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.81it/s, est. speed input: 1546.9
# Generating:   4%|██                                              | 40/913 [02:55<1:03:09,  4.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1511.0
# Generating:   4%|██▏                                             | 41/913 [02:59<1:02:25,  4.29s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1579.8
# Generating:   5%|██▏                                             | 42/913 [03:03<1:02:00,  4.27s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1474.4
# Generating:   5%|██▎                                             | 43/913 [03:07<1:01:32,  4.24s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.08it/s, est. speed input: 1481.2
# Generating:   5%|██▍                                               | 44/913 [03:11<59:46,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.05it/s, est. speed input: 1497.0
# Generating:   5%|██▍                                               | 45/913 [03:15<58:48,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1497.6
# Generating:   5%|██▌                                               | 46/913 [03:19<59:16,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1471.1
# Generating:   5%|██▌                                               | 47/913 [03:24<59:37,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1489.4
# Generating:   5%|██▋                                               | 48/913 [03:28<59:49,  4.15s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1529.6
# Generating:   5%|██▋                                               | 49/913 [03:32<59:56,  4.16s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1499.2
# Generating:   5%|██▋                                               | 50/913 [03:36<58:40,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.01it/s, est. speed input: 1479.6
# Generating:   6%|██▊                                               | 51/913 [03:40<58:17,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1535.4
# Generating:   6%|██▊                                               | 52/913 [03:44<58:48,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.01it/s, est. speed input: 1531.4
# Generating:   6%|██▉                                               | 53/913 [03:48<58:20,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1470.4
# Generating:   6%|██▉                                               | 54/913 [03:52<58:47,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1499.1
# Generating:   6%|███                                               | 55/913 [03:56<58:24,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1528.8
# Generating:   6%|███                                               | 56/913 [04:00<58:44,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.10it/s, est. speed input: 1498.4
# Generating:   6%|███                                               | 57/913 [04:04<57:29,  4.03s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1475.6
# Generating:   6%|███▏                                              | 58/913 [04:08<56:38,  3.98s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1494.1
# Generating:   6%|███▏                                              | 59/913 [04:12<56:53,  4.00s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.14it/s, est. speed input: 1479.0
# Generating:   7%|███▎                                              | 60/913 [04:16<55:47,  3.92s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.08it/s, est. speed input: 1478.3
# Generating:   7%|███▎                                              | 61/913 [04:20<55:25,  3.90s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1471.7
# Generating:   7%|███▍                                              | 62/913 [04:24<55:52,  3.94s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.10it/s, est. speed input: 1486.8
# Generating:   7%|███▍                                              | 63/913 [04:28<55:17,  3.90s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.12it/s, est. speed input: 1480.7
# Generating:   7%|███▌                                              | 64/913 [04:31<54:45,  3.87s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1472.4
# Generating:   7%|███▌                                              | 65/913 [04:35<55:18,  3.91s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.13it/s, est. speed input: 1494.0
# Generating:   7%|███▌                                              | 66/913 [04:39<54:38,  3.87s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1484.6
# Generating:   7%|███▋                                              | 67/913 [04:43<55:58,  3.97s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1544.2
# Generating:   7%|███▋                                              | 68/913 [04:48<56:53,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.96it/s, est. speed input: 1470.0
# Generating:   8%|███▊                                              | 69/913 [04:52<57:01,  4.05s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.01it/s, est. speed input: 1482.7
# Generating:   8%|███▊                                              | 70/913 [04:56<56:42,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1501.6
# Generating:   8%|███▉                                              | 71/913 [05:00<57:20,  4.09s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.04it/s, est. speed input: 1499.0
# Generating:   8%|███▉                                              | 72/913 [05:04<56:39,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1473.7
# Generating:   8%|███▉                                              | 73/913 [05:08<56:33,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1496.0
# Generating:   8%|████                                              | 74/913 [05:12<57:04,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.82it/s, est. speed input: 1559.6
# Generating:   8%|████                                              | 75/913 [05:16<58:21,  4.18s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1575.5
# Generating:   8%|████▏                                             | 76/913 [05:21<58:26,  4.19s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.04it/s, est. speed input: 1486.6
# Generating:   8%|████▏                                             | 77/913 [05:25<57:17,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.08it/s, est. speed input: 1513.2
# Generating:   9%|████▎                                             | 78/913 [05:28<56:10,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.14it/s, est. speed input: 1498.6
# Generating:   9%|████▎                                             | 79/913 [05:32<54:56,  3.95s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1505.2
# Generating:   9%|████▍                                             | 80/913 [05:36<55:52,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1475.9
# Generating:   9%|████▍                                             | 81/913 [05:40<55:53,  4.03s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.05it/s, est. speed input: 1495.1
# Generating:   9%|████▍                                             | 82/913 [05:44<55:22,  4.00s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1514.6
# Generating:   9%|████▌                                             | 83/913 [05:48<56:04,  4.05s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.13it/s, est. speed input: 1485.7
# Generating:   9%|████▌                                             | 84/913 [05:52<54:51,  3.97s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1496.9
# Generating:   9%|████▋                                             | 85/913 [05:56<54:15,  3.93s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.97it/s, est. speed input: 1472.7
# Generating:   9%|████▋                                             | 86/913 [06:00<54:46,  3.97s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.08it/s, est. speed input: 1485.7
# Generating:  10%|████▊                                             | 87/913 [06:04<54:12,  3.94s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1480.9
# Generating:  10%|████▊                                             | 88/913 [06:08<53:44,  3.91s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.13it/s, est. speed input: 1498.0
# Generating:  10%|████▊                                             | 89/913 [06:12<53:05,  3.87s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1485.1
# Generating:  10%|████▉                                             | 90/913 [06:16<54:19,  3.96s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1524.8
# Generating:  10%|████▉                                             | 91/913 [06:20<54:30,  3.98s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.00it/s, est. speed input: 1522.5
# Generating:  10%|█████                                             | 92/913 [06:24<54:34,  3.99s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1504.0
# Generating:  10%|█████                                             | 93/913 [06:28<54:05,  3.96s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1515.0
# Generating:  10%|█████▏                                            | 94/913 [06:32<54:59,  4.03s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1501.4
# Generating:  10%|█████▏                                            | 95/913 [06:36<55:33,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1475.1
# Generating:  11%|█████▎                                            | 96/913 [06:40<55:24,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1542.2
# Generating:  11%|█████▎                                            | 97/913 [06:44<55:55,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1523.4
# Generating:  11%|█████▎                                            | 98/913 [06:49<56:12,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1514.1
# Generating:  11%|█████▍                                            | 99/913 [06:52<55:06,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.15it/s, est. speed input: 1500.2
# Generating:  11%|█████▎                                           | 100/913 [06:56<53:43,  3.96s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.04it/s, est. speed input: 1493.7
# Generating:  11%|█████▍                                           | 101/913 [07:00<53:31,  3.96s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1538.8
# Generating:  11%|█████▍                                           | 102/913 [07:04<54:26,  4.03s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:05<00:00,  1.59it/s, est. speed input: 1598.6
# Generating:  11%|█████▌                                           | 103/913 [07:09<58:34,  4.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.65it/s, est. speed input: 1570.1
# Generating:  11%|█████▎                                         | 104/913 [07:14<1:00:37,  4.50s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1552.1
# Generating:  12%|█████▋                                           | 105/913 [07:18<59:18,  4.40s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1478.2
# Generating:  12%|█████▋                                           | 106/913 [07:23<57:51,  4.30s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1488.7
# Generating:  12%|█████▋                                           | 107/913 [07:26<56:06,  4.18s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1475.4
# Generating:  12%|█████▊                                           | 108/913 [07:30<55:25,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1522.5
# Generating:  12%|█████▊                                           | 109/913 [07:34<54:55,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1478.9
# Generating:  12%|█████▉                                           | 110/913 [07:38<54:35,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1485.9
# Generating:  12%|█████▉                                           | 111/913 [07:42<53:36,  4.01s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1465.2
# Generating:  12%|██████                                           | 112/913 [07:47<54:16,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1514.4
# Generating:  12%|██████                                           | 113/913 [07:50<53:30,  4.01s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.84it/s, est. speed input: 1571.7
# Generating:  12%|██████                                           | 114/913 [07:55<54:51,  4.12s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.06it/s, est. speed input: 1505.8
# Generating:  13%|██████▏                                          | 115/913 [07:59<53:53,  4.05s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1596.7
# Generating:  13%|██████▏                                          | 116/913 [08:03<54:30,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1521.7
# Generating:  13%|██████▎                                          | 117/913 [08:07<54:08,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1490.9
# Generating:  13%|██████▎                                          | 118/913 [08:11<53:49,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.04it/s, est. speed input: 1494.7
# Generating:  13%|██████▍                                          | 119/913 [08:15<53:14,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1468.9
# Generating:  13%|██████▍                                          | 120/913 [08:19<53:48,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.06it/s, est. speed input: 1513.0
# Generating:  13%|██████▍                                          | 121/913 [08:23<53:02,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1559.3
# Generating:  13%|██████▌                                          | 122/913 [08:27<53:46,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.89it/s, est. speed input: 1577.3
# Generating:  13%|██████▌                                          | 123/913 [08:31<54:24,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1479.7
# Generating:  14%|██████▋                                          | 124/913 [08:35<53:12,  4.05s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1554.1
# Generating:  14%|██████▋                                          | 125/913 [08:40<53:49,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.97it/s, est. speed input: 1487.1
# Generating:  14%|██████▊                                          | 126/913 [08:44<53:40,  4.09s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1521.1
# Generating:  14%|██████▊                                          | 127/913 [08:48<53:18,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1487.8
# Generating:  14%|██████▊                                          | 128/913 [08:52<53:44,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1518.6
# Generating:  14%|██████▉                                          | 129/913 [08:56<53:57,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.73it/s, est. speed input: 1548.8
# Generating:  14%|██████▉                                          | 130/913 [09:01<55:56,  4.29s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1547.5
# Generating:  14%|███████                                          | 131/913 [09:05<55:36,  4.27s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1496.5
# Generating:  14%|███████                                          | 132/913 [09:09<55:17,  4.25s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1465.0
# Generating:  15%|███████▏                                         | 133/913 [09:13<55:02,  4.23s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1494.3
# Generating:  15%|███████▏                                         | 134/913 [09:17<54:16,  4.18s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1503.9
# Generating:  15%|███████▏                                         | 135/913 [09:22<54:18,  4.19s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1579.5
# Generating:  15%|███████▎                                         | 136/913 [09:26<54:23,  4.20s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1474.3
# Generating:  15%|███████▎                                         | 137/913 [09:30<53:44,  4.16s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.80it/s, est. speed input: 1570.0
# Generating:  15%|███████▍                                         | 138/913 [09:34<54:55,  4.25s/it]
# ...
# Generating:  94%|█████████████████████████████████████████████▉   | 856/913 [58:51<03:55,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1509.7
# Generating:  94%|█████████████████████████████████████████████▉   | 857/913 [58:55<03:49,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1501.7
# Generating:  94%|██████████████████████████████████████████████   | 858/913 [58:59<03:47,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.00it/s, est. speed input: 1499.4
# Generating:  94%|██████████████████████████████████████████████   | 859/913 [59:03<03:41,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.81it/s, est. speed input: 1573.6
# Generating:  94%|██████████████████████████████████████████████▏  | 860/913 [59:07<03:42,  4.20s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1486.0
# Generating:  94%|██████████████████████████████████████████████▏  | 861/913 [59:11<03:35,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1478.9
# Generating:  94%|██████████████████████████████████████████████▎  | 862/913 [59:15<03:29,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.02it/s, est. speed input: 1505.9
# Generating:  95%|██████████████████████████████████████████████▎  | 863/913 [59:19<03:23,  4.07s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.15it/s, est. speed input: 1484.7
# Generating:  95%|██████████████████████████████████████████████▎  | 864/913 [59:23<03:14,  3.97s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.13it/s, est. speed input: 1484.2
# Generating:  95%|██████████████████████████████████████████████▍  | 865/913 [59:27<03:07,  3.91s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.15it/s, est. speed input: 1481.6
# Generating:  95%|██████████████████████████████████████████████▍  | 866/913 [59:31<03:01,  3.86s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1504.8
# Generating:  95%|██████████████████████████████████████████████▌  | 867/913 [59:35<02:57,  3.86s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.05it/s, est. speed input: 1494.4
# Generating:  95%|██████████████████████████████████████████████▌  | 868/913 [59:38<02:54,  3.88s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1545.3
# Generating:  95%|██████████████████████████████████████████████▋  | 869/913 [59:43<02:55,  3.99s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.87it/s, est. speed input: 1565.1
# Generating:  95%|██████████████████████████████████████████████▋  | 870/913 [59:47<02:55,  4.08s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.00it/s, est. speed input: 1477.2
# Generating:  95%|██████████████████████████████████████████████▋  | 871/913 [59:51<02:50,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.00it/s, est. speed input: 1487.1
# Generating:  96%|██████████████████████████████████████████████▊  | 872/913 [59:55<02:45,  4.05s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.96it/s, est. speed input: 1452.0
# Generating:  96%|██████████████████████████████████████████████▊  | 873/913 [59:59<02:42,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.04it/s, est. speed input: 1493.6
# Generating:  96%|████████████████████████████████████████████▉  | 874/913 [1:00:03<02:36,  4.02s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1505.3
# Generating:  96%|█████████████████████████████████████████████  | 875/913 [1:00:07<02:33,  4.04s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.75it/s, est. speed input: 1563.3
# Generating:  96%|█████████████████████████████████████████████  | 876/913 [1:00:12<02:35,  4.20s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.07it/s, est. speed input: 1496.4
# Generating:  96%|█████████████████████████████████████████████▏ | 877/913 [1:00:16<02:27,  4.10s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.02it/s, est. speed input: 1483.6
# Generating:  96%|█████████████████████████████████████████████▏ | 878/913 [1:00:20<02:22,  4.06s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1554.0
# Generating:  96%|█████████████████████████████████████████████▏ | 879/913 [1:00:24<02:19,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1524.3
# Generating:  96%|█████████████████████████████████████████████▎ | 880/913 [1:00:28<02:16,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.88it/s, est. speed input: 1570.4
# Generating:  96%|█████████████████████████████████████████████▎ | 881/913 [1:00:32<02:13,  4.18s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.99it/s, est. speed input: 1487.6
# Generating:  97%|█████████████████████████████████████████████▍ | 882/913 [1:00:36<02:08,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.98it/s, est. speed input: 1489.8
# Generating:  97%|█████████████████████████████████████████████▍ | 883/913 [1:00:40<02:03,  4.12s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.92it/s, est. speed input: 1478.6
# Generating:  97%|█████████████████████████████████████████████▌ | 884/913 [1:00:45<02:00,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.74it/s, est. speed input: 1568.7
# Generating:  97%|█████████████████████████████████████████████▌ | 885/913 [1:00:49<01:59,  4.28s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.76it/s, est. speed input: 1567.5
# Generating:  97%|█████████████████████████████████████████████▌ | 886/913 [1:00:54<01:57,  4.37s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.76it/s, est. speed input: 1578.8
# Generating:  97%|█████████████████████████████████████████████▋ | 887/913 [1:00:58<01:55,  4.42s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1560.5
# Generating:  97%|█████████████████████████████████████████████▋ | 888/913 [1:01:03<01:48,  4.36s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1525.9
# Generating:  97%|█████████████████████████████████████████████▊ | 889/913 [1:01:07<01:43,  4.32s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.05it/s, est. speed input: 1493.3
# Generating:  97%|█████████████████████████████████████████████▊ | 890/913 [1:01:11<01:36,  4.20s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.00it/s, est. speed input: 1482.3
# Generating:  98%|█████████████████████████████████████████████▊ | 891/913 [1:01:15<01:31,  4.14s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1523.1
# Generating:  98%|█████████████████████████████████████████████▉ | 892/913 [1:01:19<01:27,  4.16s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.69it/s, est. speed input: 1541.8
# Generating:  98%|█████████████████████████████████████████████▉ | 893/913 [1:01:24<01:26,  4.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.82it/s, est. speed input: 1568.1
# Generating:  98%|██████████████████████████████████████████████ | 894/913 [1:01:28<01:22,  4.36s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.87it/s, est. speed input: 1585.2
# Generating:  98%|██████████████████████████████████████████████ | 895/913 [1:01:32<01:18,  4.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.88it/s, est. speed input: 1584.3
# Generating:  98%|██████████████████████████████████████████████ | 896/913 [1:01:37<01:13,  4.32s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  2.00it/s, est. speed input: 1487.3
# Generating:  98%|██████████████████████████████████████████████▏| 897/913 [1:01:41<01:07,  4.23s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.69it/s, est. speed input: 1585.3
# Generating:  98%|██████████████████████████████████████████████▏| 898/913 [1:01:45<01:05,  4.39s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.64it/s, est. speed input: 1582.5
# Generating:  98%|██████████████████████████████████████████████▎| 899/913 [1:01:50<01:03,  4.54s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.90it/s, est. speed input: 1586.4
# Generating:  99%|██████████████████████████████████████████████▎| 900/913 [1:01:55<00:57,  4.45s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.10it/s, est. speed input: 1503.3
# Generating:  99%|██████████████████████████████████████████████▍| 901/913 [1:01:58<00:51,  4.26s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.09it/s, est. speed input: 1500.5
# Generating:  99%|██████████████████████████████████████████████▍| 902/913 [1:02:02<00:45,  4.13s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1572.5
# Generating:  99%|██████████████████████████████████████████████▍| 903/913 [1:02:06<00:41,  4.16s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.01it/s, est. speed input: 1513.8
# Generating:  99%|██████████████████████████████████████████████▌| 904/913 [1:02:10<00:37,  4.11s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.65it/s, est. speed input: 1533.7
# Generating:  99%|██████████████████████████████████████████████▌| 905/913 [1:02:15<00:34,  4.34s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1573.3
# Generating:  99%|██████████████████████████████████████████████▋| 906/913 [1:02:20<00:30,  4.30s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.83it/s, est. speed input: 1553.6
# Generating:  99%|██████████████████████████████████████████████▋| 907/913 [1:02:24<00:25,  4.33s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.91it/s, est. speed input: 1472.6
# Generating:  99%|██████████████████████████████████████████████▋| 908/913 [1:02:28<00:21,  4.29s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.81it/s, est. speed input: 1589.1
# Generating: 100%|██████████████████████████████████████████████▊| 909/913 [1:02:33<00:17,  4.33s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.82it/s, est. speed input: 1572.8
# Generating: 100%|██████████████████████████████████████████████▊| 910/913 [1:02:37<00:13,  4.36s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:03<00:00,  2.08it/s, est. speed input: 1524.5
# Generating: 100%|██████████████████████████████████████████████▉| 911/913 [1:02:41<00:08,  4.21s/it]
# Processed prompts:   0%| | 0/8 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 8/8 [00:04<00:00,  1.81it/s, est. speed input: 1593.4
# Generating: 100%|██████████████████████████████████████████████▉| 912/913 [1:02:45<00:04,  4.28s/it]
# Processed prompts:   0%| | 0/5 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, o
# Processed prompts: 100%|█| 5/5 [00:02<00:00,  1.77it/s, est. speed input: 1340.4
# Generating: 100%|███████████████████████████████████████████████| 913/913 [1:02:48<00:00,  4.13s/it]
# 2026-01-06 06:27:29 - INFO - Saved 7301 predictions to /kaggle/working/predictions_llama_few.json
# INFO:llama_infer:Saved 7301 predictions to /kaggle/working/predictions_llama_few.json
# INFO 01-06 06:27:29 multiproc_worker_utils.py:140] Terminating local vLLM worker processes
# (VllmWorkerProcess pid=297) INFO 01-06 06:27:29 multiproc_worker_utils.py:247] Worker exiting
# [rank0]:[W106 06:27:31.980905434 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ##### Few-shot

# %%
# !python /kaggle/input/evaluation-main/evaluation.py \
  /kaggle/input/uit-viquad-2-0/ground_truth_private_test.json \
  /kaggle/working/predictions_llama_few.json \
  --out-file /kaggle/working/results/evaluation_llama_few.json \
  --log-dir /kaggle/working/logs
# Out:
# 2026-01-06 06:28:40 - INFO - Logger initialized. Log file: /kaggle/working/logs/evaluation_20260106_062840.log
# 2026-01-06 06:28:40 - INFO - Loading dataset from /kaggle/input/uit-viquad-2-0/ground_truth_private_test.json
# 2026-01-06 06:28:41 - INFO - Loading predictions from /kaggle/working/predictions_llama_few.json
# 2026-01-06 06:28:41 - INFO - No na_prob_file provided, using default 0.0 for all questions
# 2026-01-06 06:28:41 - INFO - Dataset contains 19 examples
# 2026-01-06 06:28:41 - INFO - Predictions contain 7301 entries
# 2026-01-06 06:28:41 - INFO - Evaluating on 3712 questions with predictions
# 2026-01-06 06:28:41 - INFO -   Has answer: 2596
# 2026-01-06 06:28:41 - INFO -   No answer: 1116
# 2026-01-06 06:28:41 - INFO - Evaluation Results:
# 2026-01-06 06:28:41 - INFO -   Exact Match: 0.22%
# 2026-01-06 06:28:41 - INFO -   F1 Score: 28.16%
# 2026-01-06 06:28:41 - INFO -   HasAns - Exact: 0.31%
# 2026-01-06 06:28:41 - INFO -   HasAns - F1: 40.26%
# 2026-01-06 06:28:41 - INFO -   NoAns - Exact: 0.00%
# 2026-01-06 06:28:41 - INFO -   NoAns - F1: 0.00%
# 2026-01-06 06:28:41 - INFO - Saving evaluation results to /kaggle/working/results/evaluation_llama_few.json
